# %%
# !pip list
# Out:
# Package              Version
# -------------------- -----------
# anyio                3.5.0
# argon2-cffi          20.1.0
# attrs                22.1.0
# Babel                2.11.0
# backcall             0.2.0
# beautifulsoup4       4.11.1
# bleach               4.1.0
# brotlipy             0.7.0
# certifi              2022.12.7
# cffi                 1.15.1
# charset-normalizer   2.0.4
# colorama             0.4.6
# cryptography         39.0.1
# debugpy              1.5.1
# decorator            5.1.1
# defusedxml           0.7.1
# entrypoints          0.4
# fastjsonschema       2.16.2
# idna                 3.4
# importlib-metadata   4.11.3
# importlib-resources  5.2.0
# ipykernel            6.15.2
# ipython              7.31.1
# ipython-genutils     0.2.0
# ipywidgets           7.6.5
# jedi                 0.18.1
# Jinja2               3.1.2
# json5                0.9.6
# jsonschema           4.17.3
# jupyter              1.0.0
# jupyter_client       7.4.9
# ...

# %%
# !pip install torch torchvision torchaudio
# Out:
# ...
#   Using cached torchaudio-0.13.1-cp37-cp37m-win_amd64.whl (2.0 MB)
# ...

# %%
# !pip install fastai
# Out:
# ...
#   Using cached fastai-2.7.12-py3-none-any.whl (233 kB)
# ...
#   Using cached spacy-3.5.2-cp37-cp37m-win_amd64.whl (12.5 MB)
# ...
#   Using cached scipy-1.7.3-cp37-cp37m-win_amd64.whl (34.1 MB)
# ...
#   Using cached fastprogress-1.0.3-py3-none-any.whl (12 kB)
# ...
#   Using cached matplotlib-3.5.3-cp37-cp37m-win_amd64.whl (7.2 MB)
# ...
#   Using cached pandas-1.3.5-cp37-cp37m-win_amd64.whl (10.0 MB)
# ...
#   Using cached scikit_learn-1.0.2-cp37-cp37m-win_amd64.whl (7.1 MB)
# ...
#   Using cached PyYAML-6.0-cp37-cp37m-win_amd64.whl (153 kB)
# ...
#   Using cached fastdownload-0.0.7-py3-none-any.whl (12 kB)
# ...
#   Using cached fastcore-1.5.29-py3-none-any.whl (67 kB)
# ...
#   Using cached pathy-0.10.1-py3-none-any.whl (48 kB)
# ...
#   Using cached pydantic-1.10.7-cp37-cp37m-win_amd64.whl (2.1 MB)
# ...
#   Using cached srsly-2.4.6-cp37-cp37m-win_amd64.whl (481 kB)
# ...
#   Using cached catalogue-2.0.8-py3-none-any.whl (17 kB)
# ...
#   Using cached cymem-2.0.7-cp37-cp37m-win_amd64.whl (30 kB)
# ...

# %% [markdown]
# ## **PROGRAM BEGINS**

# %%
# !pip install inltk
# Out:
# ...
#   Using cached inltk-0.9-py3-none-any.whl (13 kB)
# ...
#   Using cached Bottleneck-1.3.7-cp37-cp37m-win_amd64.whl (109 kB)
# ...
#   Using cached typing-3.7.4.3-py3-none-any.whl
# ...
#   Using cached numexpr-2.8.4-cp37-cp37m-win_amd64.whl (92 kB)
# ...
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# ...
#   Using cached nvidia_ml_py3-7.352.0-py3-none-any.whl
# ...
#   Using cached aiohttp-3.8.4-cp37-cp37m-win_amd64.whl (322 kB)
# ...
#   Using cached sentencepiece-0.1.98-cp37-cp37m-win_amd64.whl (977 kB)
# ...
#   Using cached fastai-1.0.57-py3-none-any.whl (233 kB)
# ...
#   Using cached asynctest-0.13.0-py3-none-any.whl (26 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# ...
#   Using cached yarl-1.9.1-cp37-cp37m-win_amd64.whl (61 kB)
# ...
#   Using cached frozenlist-1.3.3-cp37-cp37m-win_amd64.whl (34 kB)
# ...
#   Using cached multidict-6.0.4-cp37-cp37m-win_amd64.whl (27 kB)
# ...
#   Attempting uninstall: fastai
#     Found existing installation: fastai 2.7.12
#     Uninstalling fastai-2.7.12:
# ...

# %%
# !pip install torch==1.3.1+cpu -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#   Using cached https://download.pytorch.org/whl/cpu/torch-1.3.1%2Bcpu-cp37-cp37m-win_amd64.whl (71.3 MB)
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1
#     Uninstalling torch-1.13.1:
#       Successfully uninstalled torch-1.13.1
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.14.1 requires torch==1.13.1, but you have torch 1.3.1+cpu which is incompatible.
# torchaudio 0.13.1 requires torch==1.13.1, but you have torch 1.3.1+cpu which is incompatible.

# %% [markdown]
# ### ***Run from here ->***

# %%
from inltk.inltk import setup

# %%
setup('hi')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2844\691933637.py in <module>
# ----> 1 setup('hi')
#
# ~\anaconda3\envs\pytorch_p37_2\lib\site-packages\inltk\inltk.py in setup(language_code)
#      31     loop = asyncio.get_event_loop()
#      32     tasks = [asyncio.ensure_future(download(language_code))]
# ---> 33     learn = loop.run_until_complete(asyncio.gather(*tasks))[0]
#      34     loop.close()
#      35
#
# ~\anaconda3\envs\pytorch_p37_2\lib\asyncio\base_events.py in run_until_complete(self, future)
#     561         """
#     562         self._check_closed()
# --> 563         self._check_runnung()
#     564
#     565         new_task = not futures.isfuture(future)
#
# ~\anaconda3\envs\pytorch_p37_2\lib\asyncio\base_events.py in _check_runnung(self)
#     521     def _check_runnung(self):
#     522         if self.is_running():
# ...

# %%
from inltk.inltk import tokenize

# %%
text = "इस पृष्ठ पर इन्टरनेट पर उपलब्ध विभिन्न हिन्दी एवं देवनागरी"
tokenize(text, 'hi')
# Out:
# ['▁इस',
#  '▁पृष्ठ',
#  '▁पर',
#  '▁इन्टरनेट',
#  '▁पर',
#  '▁उपलब्ध',
#  '▁विभिन्न',
#  '▁हिन्दी',
#  '▁एवं',
#  '▁देवनागरी']

# %% [markdown]
# ## **INTERCEPTION POINT**
#
# get_embedding_vectors() posed problem of:\
# LSTM has no object attribute...\
# RuntimeError: Internal: D:\a\sentencepiece\sentencepiece\src\sentencepiece_processor.cc(1102) [model_proto->ParseFromArray(serialized.data(), serialized.size())]
#
# Resolved, how?\
# *deactivated current env*\
# *created new env*
#
# Run always:\
# !pip install torch torchvision torchaudio\
# !pip install fastai\
# !pip install inltk\
# !pip install torch==1.3.1+cpu -f https://download.pytorch.org/whl/torch_stable.html\

# %%
from inltk.inltk import get_embedding_vectors

# %%
vectors = get_embedding_vectors(text, 'hi')
print(vectors)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
from inltk.inltk import predict_next_words

# %%
predict_next_words(text , 4, 'hi')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
# pip install --upgrade inltk

# %%
from inltk.inltk import get_sentence_encoding

# %%
get_sentence_encoding(text, 'hi')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %% [markdown]
# ### ***Sentence similarity***

# %%
from inltk.inltk import get_sentence_similarity

s1 = "वे पेड़ के नीचे पत्ते खेल रहे हैं"
s2 = "वे पेड़ के नीचे ताश खेल रहे हैं"
s3 = "वे पेड़ के नीचे पर्ण खेल रहे हैं"

# %%
print(get_sentence_similarity(s1, s2, 'hi'))
print(get_sentence_similarity(s1, s3, 'hi'))
print(get_sentence_similarity(s2, s3, 'hi'))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
# s1 ans s2 are closest

# %% [markdown]
# ### ***Similar sentences***

# %%
from inltk.inltk import get_similar_sentences

# %%
# s1 = "वे पेड़ के नीचे पत्ते खेल रहे हैं"
sim_sent = get_similar_sentences(s1, 10, 'hi', degree_of_aug = 0.1)
sim_sent
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
# decreasing similarity

# %%
for sentence in sim_sent:
    print(get_sentence_similarity(s1, sentence, 'hi'))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %% [markdown]
# ### ***Experiments***

# %%
# higher degree of augmentation => lesser similarity

# %%
# s1 = "वे पेड़ के नीचे पत्ते खेल रहे हैं"
sim_sent = get_similar_sentences(s1, 10, 'hi', degree_of_aug = 0.4)

for sentence in sim_sent:
    print(sentence, ":", get_sentence_similarity(s1, sentence, 'hi'))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
# s1 = "वे पेड़ के नीचे पत्ते खेल रहे हैं"
# s2 = "वे पेड़ के नीचे ताश खेल रहे हैं"
# s3 = "वे पेड़ के नीचे पर्ण खेल रहे हैं"

# %%
s1_list = get_similar_sentences(s1, 4, 'hi', degree_of_aug = 0.2)
s2_list = get_similar_sentences(s2, 4, 'hi', degree_of_aug = 0.2)
s3_list = get_similar_sentences(s3, 4, 'hi', degree_of_aug = 0.2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
s1_list
# Out:
# ['वे पेड़ के उपर पत्ते खेल रहे हैं',
#  'वे पेड़के नीचे पत्ते खेल रहे हैं',
#  'वो पेड़ के नीचे पत्ते खेल रहे हैं',
#  'वे पेड़ के नीचे पत्ते खेलों रहे हैं']

# %%
s2_list
# Out:
# ['वे पेड़के नीचे ताश खेल रहे हैं',
#  'वे पेड़ के नीचे ताश खेल रहे है',
#  'वे पेड़ों के नीचे ताश खेल रहे हैं',
#  'वो पेड़ के नीचे ताश खेल रहे हैं']

# %%
s3_list
# Out:
# ['वे पेड़ के नीचे पर्ण खेल रहे है',
#  'वे पेड़ के उपर पर्ण खेल रहे हैं',
#  'वे पेड़ के नीचे पर्ण खेल रहें हैं',
#  'वे पेड़ के नीचे पर्ण खेल रहें हैं']

# %%
# s1 = "वे पेड़ के नीचे पत्ते खेल रहे हैं"
# s2 = "वे पेड़ के नीचे ताश खेल रहे हैं"
# s3 = "वे पेड़ के नीचे पर्ण खेल रहे हैं"

# %% [markdown]
# ##### Performing tests for similarity between s1_list and s2_list sentences

# %%
for sent1 in s1_list:
    print(sent1)
    for sent2 in s2_list:
        print("   -> ", sent2, ":", get_sentence_similarity(sent1, sent2, 'hi'))
# Out:
# वे पेड़ के उपर पत्ते खेल रहे हैं
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
# ...

# %%
# s1_list[1] and s2_list[0] yielded max. overlap

# %% [markdown]
# ##### Example 2

# %%
sent1 = "इस किताब मे पन्ने की जानकारी दि है"
sent2 = "इस किताब मे हरित मण की जानकारी दि है"
sent3 = "इस किताब मे पना की जानकारी दि है"

# %%
sent1_list = get_similar_sentences(sent1, 4, 'hi', degree_of_aug = 0.2)
sent2_list = get_similar_sentences(sent2, 4, 'hi', degree_of_aug = 0.2)
sent3_list = get_similar_sentences(sent3, 4, 'hi', degree_of_aug = 0.2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
sent1_list
# Out:
# ['इस गज़ल मे पन्ने की जानकारी दि है',
#  'इस किताब मै पन्ने की जानकारी दि है',
#  'इस किताब मे पन्ने का जानकारी दि है',
#  'इस किताब मे मुखपृष्ठ की जानकारी दि है']

# %%
sent2_list
# Out:
# ['इस वृत्तचित्र मे गंड मण की जानकारी दि है',
#  'इस किताबमें हरित मण का जानकारी दि है',
#  'इस किताब मे हरित विष्ट कि जानकारी दि है',
#  'इस किताब मे मंदाकिनी ॥मण की जानकारी दि है']

# %%
sent3_list
# Out:
# ['इस किताब मे पना का जानकारी दि है',
#  'इस वृतांत मे पना की जानकारी दि है',
#  'इसके किताब मे पना की जानकारी दि है',
#  'इस किताब मे सिसना की जानकारी दि है']

# %%
for sent1 in sent1_list:
    print(sent1)
    for sent2 in sent2_list:
        print("   -> ", sent2, ":", get_sentence_similarity(sent1, sent2, 'hi'))
# Out:
# इस गज़ल मे पन्ने की जानकारी दि है
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
# ...

# %%
sent1 = "इस किताब मे पन्ने की जानकारी दि है"

print("   -> ", sent2_list[1], ":", get_sentence_similarity(sent2_list[1], sent1, 'hi'))
print("   -> ", sent2_list[0], ":", get_sentence_similarity(sent2_list[0], sent1, 'hi'))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
s = "इस किताब में हरित मण का जानकारी दि है"

# %%
get_sentence_similarity(s, sent1, 'hi')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %% [markdown]
# #### Experimentation

# %% [markdown]
# ### ***Lemmatization***

# %%
# !pip install nltk
# Out:
# ...
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# ...
#      -------------------------------------- 268.0/268.0 kB 1.0 MB/s eta 0:00:00
# ...

# %%
# -*- coding: utf-8 -*-
import io
import string
import re
import nltk
from nltk.tag import tnt
from nltk.corpus import indian


outputFile = open('testOutput.txt','w')
wordDict = {}
taggedFile  = open("output_test.txt", "r")

def checkRules():
    rules = []
    with open('rules.txt','r') as rulesFile:
        for line in rulesFile:
            line = line.strip('\n').split()
            rules.append(line)

    rulesTwo = []
    with open('rules2.txt','r') as rulesFile:
        for line in rulesFile:
            line = line.strip('\n').split()
            rulesTwo.append(line)


    taggedData = []
    prev= ['None']
    for line in taggedFile:
        prevTag = prev.pop(0)
        line= line.strip('\n').split()
        line.append(prevTag)
        currTag = line[1]
        prev.append(currTag)
        taggedData.append(line)
   
    for element in taggedData:
        if element[0]=='<s>' or element[0]=='</s>':
            
            outputFile.write(element[0] + ' ' + element[1])
            outputFile.write('\n')
            continue
        if any(char.isdigit() for char in element[0]) or element[1] == 'SYM':

            outputFile.write(element[0] + ' ' + element[0])
            outputFile.write('\n')
            continue
        flag = 0
        count = 0
        match = []
        for rule in rules:
            if element[:2] == rule[:2]:
                match.append(rule[2])
                count = count +1 

        if count==1:
            outputFile.write(element[0] + ' ' + match[0])
            outputFile.write('\n') 
            flag = 1
        
        elif count>1:
            for rule in rulesTwo:
                if element == rule[:3]:
                    outputFile.write(element[0] + ' ' + rule[3])
                    outputFile.write('\n')
                    flag = 1
                    break

        if flag == 0:
            lemma = lemmatize(element)
            outputFile.write(element[0] + ' ' + lemma)
            outputFile.write('\n')
    
def lemmatize(element):

        if element[1].strip().startswith("NN") or element[1].strip().startswith("VAUX") :
            return element[0]

        else:
        
            return generate_stem_words(element[0].strip())
    

def generate_stem_words(word):
    
    suffixes = {
    1: ["ो","े","ू","ु","ी","ि","ा"],
    2: ["कर","ाओ","िए","ाई","ाए","ने","नी","ना","ते","ीं","ती","ता","ाँ","ां","ों","ें"],
    3: ["ाकर","ाइए","ाईं","ाया","ेगी","ेगा","ोगी","ोगे","ाने","ाना","ाते","ाती","ाता","तीं","ाओं","ाएं","ुओं","ुएं","ुआं"],
    4: ["ाएगी","ाएगा","ाओगी","ाओगे","एंगी","ेंगी","एंगे","ेंगे","ूंगी","ूंगा","ातीं","नाओं","नाएं","ताओं","ताएं","ियाँ","ियों","ियां"],
    5: ["ाएंगी","ाएंगे","ाऊंगी","ाऊंगा","ाइयाँ","ाइयों","ाइयां"],
        }


    rule1 = suffixes[4][17]
    rule2 = suffixes[4][16]
    rule3 = suffixes[1][1]
    rule4 = suffixes[1][6]
    rule5 = suffixes[1][4]
    rule6 = suffixes[5][4]
    rule7 = suffixes[5][5]
    rule8 = suffixes[5][6]

    
    if word.endswith(rule1):
        return word[:word.rindex(rule1)] + suffixes[1][4]
    
    elif word.endswith(rule2):
        return word[:word.rindex(rule2)] + suffixes[1][4]

    elif word.endswith(rule3):
        return word[:word.rindex(rule3)] + suffixes[1][6]
    
    elif word.endswith(rule4):
        return word[:word.rindex(rule4)] + suffixes[1][6]
    
    elif word.endswith(rule5):
        return word[:word.rindex(rule5)] + suffixes[1][4]
    
    elif word.endswith(rule6):
        return word[:word.rindex(rule6)] + suffixes[3][2]
    
    elif word.endswith(rule7):
        return word[:word.rindex(rule7)] + suffixes[3][2]
    
    elif word.endswith(rule8):
        return word[:word.rindex(rule8)] + suffixes[3][2]
    
    else:
        
        for key in suffixes.keys():
            for value in suffixes[key]:
                if word.endswith(value):
                    suff = word.rindex(value)
                    return word[:suff]

    return word
     
    

def main():
    checkRules()
     
        
if __name__=="__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2844\364430000.py in <module>
#      10 outputFile = open('testOutput.txt','w')
#      11 wordDict = {}
# ---> 12 taggedFile  = open("output_test.txt", "r")
#      13
#      14 def checkRules():
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_test.txt'

# %% [markdown]
# ### ***pyiwn***

# %%
# !pip install --upgrade pyiwn

# %%
import pyiwn

# %%
iwn = pyiwn.IndoWordNet()
# Out:
# 2023-04-26:09:43:42,802 INFO     [iwn.py:43] Loading hindi language synsets...

# %%
word = 'पत्ता'
synsets = iwn.synsets(word)

# %%
synsets
# Out:
# [Synset('पत्ता.noun.2535'),
#  Synset('चादर.noun.5193'),
#  Synset('ताश.noun.5989'),
#  Synset('पीपरपर्न.noun.6170'),
#  Synset('पत्ता.noun.20321'),
#  Synset('पत्ता.noun.34975')]

# %%
for synset in synsets:
    print(synset.lemma_names()[0])
# Out:
# पत्ता
# चादर
# ताश
# पीपरपर्न
# पत्ता
# पत्ता

# %% [markdown]
# ##### Synset synonym overlap with max. yield sentences

# %%
# s1_list[1]: वे पेड़के नीचे पत्ते खेल रहे हैं
# s2_list[0]: वे पेड़के नीचे ताश खेल रहे हैं

for synset in synsets:
    w = synset.lemma_names()[0]
    print(synset.lemma_names())
    for wrd in synset.lemma_names():
        if wrd != word:
            w = wrd
            break
    print(w)
    print("s1:", get_sentence_similarity(s1_list[1], w, 'hi'))
    print("s2:", get_sentence_similarity(s2_list[0], w, 'hi'))
    print("--")
# Out:
# ['पत्ता', 'पात', 'पर्ण', 'पत्र', 'दल', 'छद', 'पत्रक', 'परन', 'वर्ह']
# पात
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
# ...

# %%
##### Synset synonym overlap with max. yield sentences

# %%
# s1_list[1]: वे पेड़के नीचे पत्ते खेल रहे हैं
# s2_list[0]: वे पेड़के नीचे ताश खेल रहे हैं

for synset in synsets:
    print(synset.lemma_names())
    for sent in synset.examples():
        print("s1:", get_sentence_similarity(s1, sent, 'hi'))
        print("s2:", get_sentence_similarity(s2, sent, 'hi'))
    print("--")
# Out:
# ['पत्ता', 'पात', 'पर्ण', 'पत्र', 'दल', 'छद', 'पत्रक', 'परन', 'वर्ह']
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
# ...

# %%
s1_list
# Out:
# ['वे पेड़ के उपर पत्ते खेल रहे हैं',
#  'वे पेड़के नीचे पत्ते खेल रहे हैं',
#  'वो पेड़ के नीचे पत्ते खेल रहे हैं',
#  'वे पेड़ के नीचे पत्ते खेलों रहे हैं']

# %%
word =
# Out:
#   File "C:\Users\thakr\AppData\Local\Temp\ipykernel_12392\2336514174.py", line 1
#     word =
#            ^
# SyntaxError: invalid syntax

# %%
word = 'पत्ता'
sentence = "वे पेड़ के नीचे पत्ते खेल रहे हैं"
synsets = iwn.synsets(word)
s = []

for synset in synsets:
    w = synset.lemma_names()[0]
    # print(synset.lemma_names())
    for wrd in synset.lemma_names():
        if wrd != word:
            s.append(sentence.replace("पत्ते", wrd))
            break
            
s
# Out:
# ['वे पेड़ के नीचे पात खेल रहे हैं',
#  'वे पेड़ के नीचे चादर खेल रहे हैं',
#  'वे पेड़ के नीचे ताश खेल रहे हैं',
#  'वे पेड़ के नीचे पीपरपर्न खेल रहे हैं']

# %%
# get similar sentences of these four sentences

# %%
for sent in s:
    sim_sent_list = get_similar_sentences(sent, 4, 'hi', degree_of_aug = 0.2)
    for sen in sim_sent_list:
        print(sen, ":", get_sentence_similarity(sen, sentence, 'hi'))
    print()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %% [markdown]
# ##### Results
#
# वे पेड़ के नीचे पात खेल रहे है : 0.8769082427024841\
# वे पेड़ों के नीचे पात खेल रहे हैं : 0.8740048408508301\
# वे पेड़ के नीचे झूला खेल रहे हैं : 0.8995546698570251\
# **वे पेड़ के नीचे शिखा खेल रहे हैं : 0.9245168566703796**\
# \
# वे पेड़ के नीचे चादर खेल रहे है : 0.8997978568077087\
# **वे पेड़ की नीचे चादर खेल रहे हैं : 0.9247074127197266**\
# **वे पेड़ के उपर चादर खेल रहे हैं : 0.900107741355896**\
# वे पेड़ के नीचे चादर खेल रहें हैं : 0.8926532864570618\
# \
# **वे पेड़के नीचे ताश खेल रहे हैं : 0.9055671095848083**\
# ***वे पेड़के नीचे ताश खेल रहे हैं : 0.9055671095848083***\
# **वे पेड़ की नीचे ताश खेल रहे हैं : 0.9218146204948425**\
# वो पेड़ के नीचे ताश खेल रहे हैं : 0.8833142518997192\
# \
# वे पेड़के ऊपर पीपरपर्न खेल रहे हैं : 0.8199869990348816\
# वे पेड़ के उपर पी्सेपर्न खेल रहे हैं : 0.8609452843666077\
# वो पेड़ के नीचे पीपरपसर्न खेल रहे हैं : 0.7994949817657471\
# वे पेड़ के नीचे पीपरप्रर्न खेल रहे है : 0.8322130441665649
